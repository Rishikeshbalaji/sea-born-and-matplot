# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline

# %%
sns.set(color_codes=True)

# %%
df=pd.read_csv('cars.csv')
df
# Out:
#                        Model  Actual_MPG  Cylinders  Engine_Disp  Horsepower  \
# 0         amc ambassador dpl        15.0          8        390.0         190
# 1                amc gremlin        21.0          6        199.0          90
# 2                 amc hornet        18.0          6        199.0          97
# 3              amc rebel sst        16.0          8        304.0         150
# 4    buick estate wagon (sw)        14.0          8        455.0         225
# ..                       ...         ...        ...          ...         ...
# 387         mazda glc custom        31.0          4         91.0          68
# 388       mazda glc custom l        37.0          4         91.0          68
# 389         nissan stanza xe        36.0          4        120.0          88
# 390         toyota celica gt        32.0          4        144.0          96
# 391           toyota corolla        34.0          4        108.0          70
#
#      Weight  Accelerate  Year    Origin
# ...

# %%
# box plot
sns.boxplot(df['Actual_MPG'])
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# violinplot
sns.violinplot(df['Actual_MPG'])
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# seting figer size
sns.displot(df['Actual_MPG'],height=8, aspect=11/8)
plt.show()

# %%
sns.displot(df['Actual_MPG'], kde= False, bins=20, rug=True)
plt.show()

# %%
sns.displot(df['Actual_MPG'], kde= True, bins=20, rug=True)
plt.show()

# %%
sns.jointplot(df['Actual_MPG'],df['Horsepower'] ,data=df, space=0, color="b")                                    
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df['Actual_MPG'],df['Horsepower'] ,data=df, space=0, color="b", )
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(y= df['Actual_MPG'], x= df['Horsepower'], kind='kde', data= df, cset =8)
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\distributions.py:1210: UserWarning: The following kwargs were not used by contour: 'cset'
#   cset = contour_func(

# %%
df.corr()
sns.pairplot(data=df)
plt.show()

# %%
sns.pairplot(data=df, kind='kde')
plt.show()
