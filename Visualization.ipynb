# %%
# Visualization

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from scipy import stats

# %%
iris=sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 1. Plot Histograms using iris dataset
plt.hist(iris.sepal_length)
plt.show()

# %%
# 2. Plot Area Plot using iris dataset
iris.plot.area()
# Out:
# <AxesSubplot:>

# %%
# 3. Plot Densityplot using iris dataset
sns.kdeplot(iris.sepal_length)
plt.show()

# %%
# 4. Plot Histograms with Densityplot using iris dataset
sns.histplot(iris.sepal_length)
plt.show()

# %%
# 5. Plot Boxplots using the iris dataset
plt.boxplot(iris.petal_width)
plt.show()

# %%
#  6. Plot Horizontal Boxplots using the iris dataset
plt.boxplot(iris.petal_width,vert= False)
plt.show()

# %%
 # 7. Plot Violinplots using the iris dataset
sns.violinplot(iris.petal_width)
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_width'>

# %%
# 8. Plot Horizontal Violinplots using the iris dataset
sns.violinplot(iris.petal_width)
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='petal_width'>

# %%
# 9. Plot Bar Plot for the following dictionary
x= iris.petal_width
y= iris.species
plt.bar(y, x, width=0.4,align='edge')
plt.show()

# %%
#  10. Plot Scatter Plot for the following dictionary
data={'apple':10,'orange':15,'lemon':5,'lime':20}

# %%
print(data)
# plt.scatter(apple,orange)
# Out:
# {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}

# %%
x= data.keys()
y=data.values()
print(x)
print(y)
plt.scatter(x,y)
# Out:
# dict_keys(['apple', 'orange', 'lemon', 'lime'])
# dict_values([10, 15, 5, 20])

# %%
# 11.  Plot Line Chart for the following dictionary
x= data.keys()
y=data.values()
print(x)
print(y)
plt.plot(x)
plt.show()
# Out:
# dict_keys(['apple', 'orange', 'lemon', 'lime'])
# dict_values([10, 15, 5, 20])

# %%
# 12. Plot Scatter Plots using iris dataset
plt.scatter(iris.species,iris.sepal_length)

# %%
# 13. Plot double Bar plot for the following data also addlegends
labels=['G1','G2','G3','G4','G5'] 
men_means=[20,34,30,35,27]
women_means=[25,32,34,20,25]
plt.bar(men_means,women_means)
plt.legend(labels)

# %%
# 14. Plot Pie Chart for the following data also addlegends
labels=['Frogs','Hogs','Dogs','Logs']
sizes=[15,30,45,10]
explode=(0,0.1,0,0)

# %%
plt.pie(sizes,explode,autopct='%1.2f')
plt.legend(labels)
plt.show()

# %%
# 15. Plot KDE plots using the iris dataset
sns.kdeplot(iris.sepal_length,color='b', shade=True)
plt.show()

# %%
# 16. Plot pair plots for the iris dataset
sns.pairplot(iris, hue ='petal_width')
plt.show()

# %%
# 17 Draw a scatterplot with marginal histograms using irisdataset
sns.jointplot("sepal_width", "petal_length", data=iris,kind="kde", space=0, color="g")                                    
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#  18. Replace the above scatterplots and histograms with density estimates and align the marginal Axes tightly with thejoint Axes
sns.jointplot("sepal_width", "petal_length", data=iris, kind='kde', space=0,hue="species", color="g")
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 19. Plot Heatmap for iris dataset with correlations in it
iris.corr()
sns.heatmap(iris.corr(),annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
#20. Plot a 3D Scatterplot for iris dataset
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
x = iris.sepal_length
y = iris.sepal_width
z = iris.petal_length
# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=x, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# legend
plt.legend(iris.species)
plt.show()
