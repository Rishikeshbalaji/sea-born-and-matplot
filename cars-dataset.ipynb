# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('cars.csv')
df
# Out:
#                        Model  Actual_MPG  Cylinders  Engine_Disp  Horsepower  \
# 0         amc ambassador dpl        15.0          8        390.0         190
# 1                amc gremlin        21.0          6        199.0          90
# 2                 amc hornet        18.0          6        199.0          97
# 3              amc rebel sst        16.0          8        304.0         150
# 4    buick estate wagon (sw)        14.0          8        455.0         225
# ..                       ...         ...        ...          ...         ...
# 387         mazda glc custom        31.0          4         91.0          68
# 388       mazda glc custom l        37.0          4         91.0          68
# 389         nissan stanza xe        36.0          4        120.0          88
# 390         toyota celica gt        32.0          4        144.0          96
# 391           toyota corolla        34.0          4        108.0          70
#
#      Weight  Accelerate  Year    Origin
# ...

# %%
plt.plot(df['Weight'], df.Origin)
plt.show()

# %%
df.corr()
# Out:
#              Actual_MPG  Cylinders  Engine_Disp  Horsepower    Weight  \
# Actual_MPG     1.000000  -0.777618    -0.805127   -0.778427 -0.832244
# Cylinders     -0.777618   1.000000     0.950823    0.842983  0.897527
# Engine_Disp   -0.805127   0.950823     1.000000    0.897257  0.932994
# Horsepower    -0.778427   0.842983     0.897257    1.000000  0.864538
# Weight        -0.832244   0.897527     0.932994    0.864538  1.000000
# Accelerate     0.423329  -0.504683    -0.543800   -0.689196 -0.416839
# Year           0.580541  -0.345647    -0.369855   -0.416361 -0.309120
#
#              Accelerate      Year
# Actual_MPG     0.423329  0.580541
# Cylinders     -0.504683 -0.345647
# Engine_Disp   -0.543800 -0.369855
# Horsepower    -0.689196 -0.416361
# Weight        -0.416839 -0.309120
# Accelerate     1.000000  0.290316
# Year           0.290316  1.000000

# %%
# heat mam seaborn
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# color palettes.
sns.heatmap(df.corr(), annot=True, cmap='rocket')
# Out:
# <AxesSubplot:>

# %%
# removing Cylinders and Year vlaues fom the data set since it not useful to analyse the data set 
data=df.drop(columns=['Cylinders','Year'])

# %%
data.corr()
# Out:
#              Actual_MPG  Engine_Disp  Horsepower    Weight  Accelerate
# Actual_MPG     1.000000    -0.805127   -0.778427 -0.832244    0.423329
# Engine_Disp   -0.805127     1.000000    0.897257  0.932994   -0.543800
# Horsepower    -0.778427     0.897257    1.000000  0.864538   -0.689196
# Weight        -0.832244     0.932994    0.864538  1.000000   -0.416839
# Accelerate     0.423329    -0.543800   -0.689196 -0.416839    1.000000

# %%
sns.heatmap(data.corr(), annot=True, cmap='rocket')
plt.figure(figsize=(10,5))
plt.show()

# %%
# sea born barplot of Engine and Horsepower
sns.barplot(df.Engine_Disp, df.Horsepower, data=df)
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# draw a bar plot with Accelerate  and origin, year with one as hue
sns.barplot(y=df.Accelerate, x=df.Origin, data=df, palette='Blues',hue='Origin')
plt.show()

# %%
# draw a bar plot with Accelerate  and Year, year with one as hue
sns.barplot(y=df.Weight, x=df.Year, data=df, palette='Blues', hue='Origin')
plt.show()

# %%
# draw a countplot for each variable model, origin year 
sns.countplot(x="Origin",hue="Model", data=df)
plt.show()

# %%
sns.countplot(x='Model',hue='Origin', data=df)
plt.show()

# %%
sns.countplot(x='Model',hue='Year', data=df)
plt.show()

# %%
sns.countplot(x='Year',hue='Origin', data=df)
plt.show()

# %%
sns.boxplot(x=df.Accelerate,y= df.Engine_Disp)
# Out:
# <AxesSubplot:xlabel='Accelerate', ylabel='Engine_Disp'>

# %%
# stripplot used to find the dencity 
sns.stripplot(x=df.Year, y=df.Engine_Disp, hue='Origin',data=df)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Engine_Disp'>

# %%
# join plot 
sns.jointplot(df.Horsepower,df.Accelerate ,data=df, space=0, color="b")                                    
plt.show()
# Out:
# C:\Users\Renuka\Desktop\jupiter_lab\env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
